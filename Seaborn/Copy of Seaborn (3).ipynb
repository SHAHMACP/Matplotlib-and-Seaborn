# %% [markdown]
# # Scatter Plot

# %%
import seaborn as sns

# Load the "tips" dataset
tips = sns.load_dataset("tips")

# Scatter plot of 'total_bill' vs 'tip'
sns.scatterplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# Variations for Grouping
#
# ---

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="day")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", size="size", sizes=(10, 100))
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", style="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
import seaborn as sns

# Load the dataset
tips = sns.load_dataset("tips")

# Scatter plot with grouping

sns.scatterplot(
    data=tips,
    x="total_bill",         # X-axis
    y="tip",                # Y-axis
    hue="smoker",           # Grouping by 'smoker' (categorical)
    size="size",            # Scaling points by 'size' (numerical)
    style="sex",            # Marker style based on 'sex' (categorical)
    sizes=(20, 200),        # Define size range for points
    alpha=0.7               # Set transparency
)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Adjust legend
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
tips = sns.load_dataset("tips")

# Scatter plot with grouping
plt.figure(figsize=(8, 6))
sns.scatterplot(
    data=tips,
    x="total_bill",         # X-axis
    y="tip",                # Y-axis
    hue="smoker",           # Grouping by 'smoker' (categorical)
    size="size",            # Scaling points by 'size' (numerical)
    style="sex",            # Marker style based on 'sex' (categorical)
    sizes=(20, 200),        # Define size range for points
    alpha=0.7               # Set transparency
)
plt.title("Scatter Plot Grouped by Smoker, Sex, and Size")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.legend(bbox_to_anchor=(1, 1))  # Adjust legend # loc = 'upper right'
plt.show()

# %% [markdown]
# Custom colors
#
# ---

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",hue="smoker",style='sex', palette = 'viridis')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",color='r')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Line Plot
#
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
tips = sns.load_dataset("tips")

# Basic line plot
sns.lineplot(data=tips, x="size", y="total_bill", color='r')
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %% [markdown]
# Grouping based on line color
#
# ---

# %%
# Line plot grouped by 'day'

sns.lineplot(data=tips, x="size", y="total_bill", hue="day", palette='coolwarm')
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %% [markdown]
# Confidence interval Cusomization
#
# ---

# %%
sns.lineplot(data=tips, x="size", y="total_bill", hue="day") # ci = 'sd'/50%

plt.show()

# %% [markdown]
# Grouping based on line style
#
# ---

# %%
# Line plot grouped by 'day' and styled by 'sex'

sns.lineplot(data=tips, x="size", y="total_bill", hue="day", style="sex")

plt.show()

# %% [markdown]
# Grouping based on line thickness
#
# ---

# %%
# Line plot grouped by 'day', styled by 'sex', and sized by 'tip'

sns.lineplot(data=tips, x="size", y="total_bill",  size="sex", sizes=(1, 5)5)

plt.show()

# %% [markdown]
# # Pair Plot
#
# ---

# %%
import seaborn as sns

# Load the dataset
tips = sns.load_dataset("tips")

# Basic pairplot
sns.pairplot(tips)

# %%
# Pairplot with hue for grouping by 'sex'
sns.pairplot(tips, hue="sex")
plt.show()

# %%
# Pairplot with customized markers
sns.pairplot(tips, hue="sex", markers=["o", "s"], diag_kind='hist')

# %%
# Pairplot with KDE plots on the diagonal (kde)
sns.pairplot(tips, diag_kind="kde")

# %%
# Pairplot with regression line on the off-diagonal plots (kde)
sns.pairplot(tips, kind="reg")

# %%
# Pairplot with only the lower triangle (corner plot)
sns.pairplot(tips, corner=True)

# %% [markdown]
# height ans aspect
#
# ---

# %%
# Pairplot with only the lower triangle (corner plot)
sns.pairplot(tips, corner=True, height = 5, aspect= 2)

# %% [markdown]
# # Count plot
#
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
tips = sns.load_dataset('tips')

# Basic count plot
sns.countplot(x='day', data=tips)

# Add title and labels
plt.title('Count of Observations by Day')
plt.xlabel('Day of the Week')
plt.ylabel('Count')

# Show the plot
plt.show()

# %% [markdown]
# Plot the bars horizontally
#
# ---

# %%
sns.countplot(y='day', data=tips)

plt.show()

# %% [markdown]
# Changing the Color of the Bars
#
# ---

# %%
sns.countplot(x='day', data=tips, color='salmon')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
# using a palette
sns.countplot(x='day', data=tips, palette='rocket')
# Out:
# <ipython-input-414-7a1bd0ca1c9b>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='day', data=tips, palette='rocket')
# <Axes: xlabel='day', ylabel='count'>

# %% [markdown]
# Rotating the Labels
#
# ---

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x='day', data=tips)
plt.xticks(rotation=45)  # Rotate x-axis labels
plt.show()

# %% [markdown]
# Count Plot with Multiple Categories
#
# ---

# %%
sns.countplot(x='day', hue='sex', data=tips)
plt.title('Count of Observations by Day and Gender')
plt.show()

# %% [markdown]
# Count Plot with Custom Order of Categories
#
# ---

# %%
sns.countplot(x='day', data=tips, order=['Sun', 'Sat', 'Thur', 'Fri'])
plt.show()

# %% [markdown]
# # Bar Plot
#
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
tips = sns.load_dataset('tips')

# Basic bar plot
sns.barplot(x='day', y='total_bill', data=tips, order=['Sun', 'Sat', 'Thur', 'Fri'])

plt.title('Average Total Bill by Day')
plt.show()

# %% [markdown]
# Horizontal Bar Plot:
#
# ---

# %%
sns.barplot(y='day', x='total_bill', data=tips)

plt.title('Horizontal Bar Plot')
plt.show()

# %% [markdown]
# Control the bar width by customizing figure size:
#
# ---

# %%
plt.figure(figsize=(20, 6))
sns.barplot(x='day', y='total_bill', data=tips)
plt.title('Bar Width Customization')
plt.show()

# %% [markdown]
# Customizing Aggregation
#
# ---

# %%
import numpy as np

# Bar plot with sum aggregation (Change to sum, median, std, or any custom function.)
sns.barplot(x='sex', y='total_bill', data=tips, estimator='sum')

plt.title('Sum Total Bill by Day')
plt.show()

# %% [markdown]
# Adding Hue for Grouping
#
# ---

# %%
sns.barplot(x='day', y='total_bill', hue='sex', data=tips, palette='pastel', dodge=False)

plt.title('Average Total Bill by Day and Gender')
plt.show()

# %% [markdown]
# Error Bars Customization
#
# ---

# %%
sns.barplot(x='day', y='total_bill', data=tips, errorbar=None)
plt.title('Bar Plot with no Error Bars')
plt.show()

# %%
#errorbar ='sd' : Shows standard deviation instead of confidence interval
sns.barplot(x='day', y='total_bill', data=tips, errorbar='sd')
plt.title('Bar Plot with Standard Deviation')
plt.show()

# %% [markdown]
# Using Custom Colors
#
# ---

# %%
sns.barplot(x='day', y='total_bill', data=tips, palette='rocket')

plt.title('Bar Plot with Custom Colors')
plt.show()

#Popular palettes: pastel, dark, muted, rocket, coolwarm
# Out:
# <ipython-input-425-23b9190e3dd0>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='day', y='total_bill', data=tips, palette='rocket')

# %%
import pandas as pd

# Customize specific bars
custom_palette = ['gray', 'red', 'gray', 'gray']
sns.barplot(x='day', y='total_bill', data=tips, palette=custom_palette)

plt.title('Highlighting a Specific Bar')
plt.show()
# Out:
# <ipython-input-10-e98a69906aa0>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='day', y='total_bill', data=tips, palette=custom_palette)

# %% [markdown]
# # Box Plot
#
# ---

# %% [markdown]
# Simple Box Plot
#
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
tips = sns.load_dataset('tips')

# Create a basic box plot
sns.boxplot(y='total_bill', data=tips)

plt.title('Distribution of Total Bill')
plt.show()

# %% [markdown]
# Grouped Box Plot
#
# ---

# %%
sns.boxplot(x='day', y='total_bill', data=tips)

plt.title('Total Bill Distribution by Day')
plt.show()

# %% [markdown]
# Adding Colors
#
# ---

# %%
sns.boxplot(x='day', y='total_bill', data=tips, palette='pastel')

plt.title('Customized Box Plot with Colors')
plt.show()
# Out:
# <ipython-input-429-8a555eeed3db>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day', y='total_bill', data=tips, palette='pastel')

# %% [markdown]
# Including Hue
#
# ---

# %%
sns.boxplot(x='smoker', y='total_bill', hue='sex', data=tips, palette='Set2')

plt.title('Total Bill Distribution by Day and Gender')
plt.show()

# %% [markdown]
# Outlier Customization
#
# ---

# %%
sns.boxplot(x='day', y='total_bill', data=tips, showfliers=False)
#showfliers=False for hiding outliers
plt.title('Box Plot without Outliers')
plt.show()

# %% [markdown]
# Horizontal Box Plot
#
# ---

# %%
sns.boxplot(x='total_bill', y='day', data=tips)
# categorical variable on y axis and numerical on x axis
plt.title('Horizontal Box Plot')
plt.show()

# %% [markdown]
# # Violin Plot
#
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load tips dataset
tips = sns.load_dataset('tips')

# Create a violin plot
sns.violinplot(x='day', y='total_bill', data=tips)
plt.title('Distribution of Total Bill by Day')

plt.show()

# %% [markdown]
# Horizontal Violin Plot
#
# ---

# %%
sns.violinplot(y='day', x='total_bill', data=tips)
plt.title('Horizontal Distribution of Total Bill by Day')

plt.show()

# %% [markdown]
# Adding Categories with hue
#
# ---

# %%
sns.violinplot(x='smoker', y='total_bill',data=tips, hue='sex')
plt.title('Total Bill by Day and Gender')
plt.show()

# %% [markdown]
# Splitting violins (split=True)
#
# ---

# %%
sns.violinplot(x='smoker', y='total_bill',data=tips, hue='sex', split = True)
plt.title('Total Bill by Day and Gender')
plt.show()

# %%
sns.violinplot(x='smoker', y='total_bill',data=tips, hue='sex', split=True)
plt.title('Total Bill by Day and Gender')
plt.show()

# %% [markdown]
# Control KDE extension
#
# ---

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
plt.title('Distribution of Total Bill (Without Outliers)')
plt.show()

# %% [markdown]
# # Histogram
#
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
tips = sns.load_dataset('tips')

# Basic histogram
sns.histplot(tips['total_bill'])
plt.title('Distribution of Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Adding Kernel Density Estimate (KDE)
#
# ---

# %%
sns.histplot(tips['total_bill'], kde=True)
plt.title('Distribution of Total Bill with KDE')

plt.show()

# %% [markdown]
# Customizing Number of Bins
#
# ---

# %%
sns.histplot(tips['total_bill'], bins=20,kde=True)
plt.title('Histogram with Custom Bins')

plt.show()

# %% [markdown]
# Grouped Histograms with hue
#
# ---

# %%
sns.histplot(data=tips, x='total_bill', hue='sex')
plt.title('Total Bill Distribution by Gender')

plt.show()

# %%
sns.histplot(data=tips, x='total_bill', hue='sex', multiple='dodge') #multiple='stack'/'dodge'/'layer'
plt.title('Total Bill Distribution by Gender')

plt.show()

# %%
sns.histplot(data=tips, x='total_bill', hue='sex', multiple='stack') #multiple='stack'/'dodge'/'layer'
plt.title('Total Bill Distribution by Gender')

plt.show()

# %%
sns.histplot(data=tips, x='total_bill', hue='sex', multiple='layer') #multiple='stack'/'dodge'/'layer'
plt.title('Total Bill Distribution by Gender')

plt.show()

# %% [markdown]
# color and palatte
#
# ---

# %%
sns.histplot(tips['total_bill'], color='green')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=tips, x='total_bill', hue='sex', multiple='dodge',palette='viridis')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
peng=sns.load_dataset("penguins")
peng
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# # KDE Plot
#
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
tips = sns.load_dataset('tips')

# Basic KDE plot
sns.kdeplot(tips['total_bill'])
plt.title('KDE Plot of Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Density')
plt.show()

# %%
sns.kdeplot(y=tips['total_bill'])
# Out:
# <Axes: xlabel='Density', ylabel='total_bill'>

# %% [markdown]
# fill the area covered by curve
#
# ---

# %%
sns.kdeplot(tips['total_bill'], fill = True, color='r')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# Change the color
#
# ---

# %%
sns.kdeplot(tips['total_bill'], fill = True, color = 'purple')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# Use Vertical to draw indicates whether to draw on the X axis or on the Y axis
#
# ---

# %%
sns.kdeplot(y=tips['total_bill'], fill = True, color = 'purple')
# Out:
# <Axes: xlabel='Density', ylabel='total_bill'>

# %% [markdown]
# Multiple KDEs on the Same Plot using hue
#
# ---

# %%
sns.kdeplot(data=tips, x='total_bill', hue='sex', common_norm=False)
plt.title('KDE Plot of Total Bill by Gender')
plt.xlabel('Total Bill')
plt.ylabel('Density')
plt.show()

# %%
sns.kdeplot(data=tips, x='total_bill', hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data=tips, x='total_bill', hue='sex', common_norm=False)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# Bivariate Kdeplot for two variables
#
# ---

# %%
sns.kdeplot(x=tips['size'], y=tips['total_bill'])
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.kdeplot(x=tips['size'], y=tips['total_bill'],fill=True)
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.kdeplot(data=tips, x='total_bill', hue='sex', shade=True, common_norm=False)
plt.title('KDE Plot of Total Bill by Gender')
plt.xlabel('Total Bill')
plt.ylabel('Density')
plt.show()
# Out:
# <ipython-input-22-dbaed1182e29>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=tips, x='total_bill', hue='sex', shade=True, common_norm=False)

# %% [markdown]
# # Rug Plot
#
# ---

# %%
import seaborn as sns

# Load the tips dataset
tips = sns.load_dataset('tips')

# Basic rug plot
sns.rugplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the tips dataset
tips = sns.load_dataset('tips')

# Basic rug plot
sns.rugplot(tips['total_bill'])
plt.title('Rug Plot of Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Density')
plt.show()

# %%
sns.rugplot(tips['total_bill'], color ='g')
# Out:
# <Axes: xlabel='total_bill'>

# %% [markdown]
# Overlaying a Rug Plot with KDE
#
# ---

# %%
sns.kdeplot(tips['total_bill'])
sns.rugplot(tips['total_bill'])
plt.title('KDE Plot with Rug Plot for Total Bill')

plt.show()

# %% [markdown]
# Overlaying a Rug Plot with a Histogram
#
# ---

# %%
sns.histplot(tips['total_bill'])
sns.rugplot(tips['total_bill'], color='r')
plt.title('Histogram with Rug Plot for Total Bill')

plt.show()

# %% [markdown]
# Changing the Rug Plot Orientation
#
# ---

# %%
sns.rugplot(y=tips['total_bill'], color='green')
plt.title('Vertical Rug Plot of Total Bill')
plt.xlabel('Density')
plt.ylabel('Total Bill')
plt.show()

# %% [markdown]
# Customizing the Ticks
#
# ---

# %%
sns.rugplot(tips['total_bill'], color='purple', height=0.4)
# Out:
# <Axes: xlabel='total_bill'>

# %% [markdown]
# # **Outlier Detection and Analysis**

# %% [markdown]
# # Swarm Plot

# %%
import seaborn as sns

tips = sns.load_dataset('tips')

sns.swarmplot(x='total_bill', data=tips)
# Out:
# <Axes: xlabel='total_bill'>

# %%
import seaborn as sns

tips = sns.load_dataset('tips')

sns.swarmplot(x='day', y='tip', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
import matplotlib.pyplot as plt

# Create a swarm plot with hue to separate Male and Female
sns.swarmplot(x='day', y='tip', data=tips, hue='sex')

# Add a title to the plot
plt.title('Swarm Plot of Tips by Day of the Week (Colored by Gender)')

# Show the plot
plt.show()

# %%
sns.swarmplot(x='day', y='tip', data=tips, hue='sex', dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
# Create a customized swarm plot
sns.swarmplot(x='day', y='tip', data=tips, hue='sex', size=8)

# Add a title to the plot
plt.title('Customized Swarm Plot of Tips by Day of the Week')

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 11.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 14.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 14.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 19.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# Create a swarm plot for total_bill vs. tip, colored by 'sex'
sns.swarmplot(x='total_bill', y='tip', data=tips, )

# Add title
plt.title('Swarm Plot for Multivariate Features (total_bill vs. tip)')

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
sns.swarmplot(x='day', y='tip', data=tips)
plt.subplot(1,2,2)
sns.boxplot(x='day', y='tip', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
# Create a box plot and overlay a swarm plot for better comparison
sns.boxplot(x='day', y='tip', data=tips)
sns.swarmplot(x='day', y='tip', data=tips, color='k', alpha=0.5)

# Add a title to the plot
plt.title('Box Plot and Swarm Plot of Tips by Day of the Week')

# Show the plot
plt.show()

# %%
# Create a box plot and overlay a swarm plot for better comparison
sns.boxplot(x='total_bill', data=tips)
sns.swarmplot(x='total_bill', data=tips, color='r', alpha=0.5)

# Add a title to the plot
plt.title('Box Plot and Swarm Plot of Total bill')

# Show the plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
tips = sns.load_dataset('tips')

# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = tips['total_bill'].quantile(0.25)
Q3 = tips['total_bill'].quantile(0.75)

# Calculate the IQR
IQR = Q3 - Q1

# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the dataset to remove outliers
filtered_tips = tips[(tips['total_bill'] >= lower_bound) & (tips['total_bill'] <= upper_bound)]

# Create a box plot and overlay a swarm plot with filtered data
sns.boxplot(x='total_bill', data=filtered_tips)
sns.swarmplot(x='total_bill', data=filtered_tips, color='r', alpha=0.5)

# Add a title to the plot
plt.title('Box Plot and Swarm Plot of Total Bill (Outliers Removed)')
plt.show()

# %% [markdown]
# # **Correlation Analysis**

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
numeric_tips = tips[['total_bill','tip','size']]
numeric_tips
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
# Compute correlation matrix
correlation_matrix = numeric_tips.corr()
correlation_matrix
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# Display the heatmap
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, fmt='.6f')
plt.show()

# %%
# Plot the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')

# Add title
plt.title('Heatmap of Feature Correlations')
plt.show()

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=10, linecolor='k')
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the penguins dataset
penguins = sns.load_dataset('penguins')

# Display the first few rows of the dataset
print(penguins.head())

# Select only numeric columns for correlation
numeric_penguins = penguins[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']]

# Compute the correlation matrix
correlation_matrix = numeric_penguins.corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Heatmap of Correlation Matrix - Penguins Dataset')
plt.show()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# # Feature Scaling Visualizations

# %% [markdown]
# MinMaxScaler
#
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
tips = sns.load_dataset('tips')
#numeric_tips = tips[['total_bill', 'tip', 'size']]  # Select numeric columns

# %%
scaler_minmax = MinMaxScaler()
tips['total_bill_MinMax'] = scaler_minmax.fit_transform(tips[['total_bill']])
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  total_bill_MinMax
# 0       16.99  1.01  Female     No  Sun  Dinner     2           0.291579
# 1       10.34  1.66    Male     No  Sun  Dinner     3           0.152283
# 2       21.01  3.50    Male     No  Sun  Dinner     3           0.375786
# 3       23.68  3.31    Male     No  Sun  Dinner     2           0.431713
# 4       24.59  3.61  Female     No  Sun  Dinner     4           0.450775

# %%
plt.figure(figsize=(12, 4))

# Original Data
plt.subplot(1, 2, 1)
sns.histplot(tips['total_bill'], kde=True, color='blue')
plt.title('Original Total Bill')

# Min-Max Scaled Data
plt.subplot(1, 2, 2)
sns.histplot(tips['total_bill_MinMax'], kde=True, color='green')
plt.title('Min-Max Scaled Total Bill')

plt.show()

# %% [markdown]
# Standardization Visualization
#
# ---

# %%
import seaborn as sns
from sklearn.preprocessing import StandardScaler

tips = sns.load_dataset('tips')

scaler_standard = StandardScaler()
tips['total_bill_Standard'] = scaler_standard.fit_transform(tips[['total_bill']])

sns.histplot(tips['total_bill_Standard'], kde=True)
# Out:
# <Axes: xlabel='total_bill_Standard', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
tips = sns.load_dataset('tips')

scaler_standard = StandardScaler()
tips['total_bill_Standard'] = scaler_standard.fit_transform(tips[['total_bill']])

# %%
plt.figure(figsize=(12, 4))

# Original Data
plt.subplot(1, 2, 1)
sns.histplot(tips['total_bill'], kde=True, color='blue')
plt.title('Original Total Bill')

# Standardized Data
plt.subplot(1, 2, 2)
sns.histplot(tips['total_bill_Standard'], kde=True, color='orange')
plt.title('Standardized Total Bill')

plt.show()

# %% [markdown]
# # Feature Transformation Visualizations
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import boxcox

# %%
# Load the tips dataset
tips = sns.load_dataset('tips')

# %% [markdown]
# log transformation
#
# ---

# %%
# Apply log transformation
log_transformed = np.log(tips['total_bill']+ 1)

# %%
plt.figure(figsize=(10, 4))

# Original Data
plt.subplot(1, 2, 1)
sns.histplot(tips['total_bill'], kde=True, color='blue')
plt.title('Original Data')

# Log Transformed Data
plt.subplot(1, 2, 2)
sns.histplot(log_transformed, kde=True, color='green')
plt.title('Log Transformed Data')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Train-Test Split Visualizations
#
# ---

# %%
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Step 1: Load the tips dataset
data = sns.load_dataset("tips")

# Step 2: Split the data into training and test sets
train_data, test_data = train_test_split(data, test_size=0.3, random_state=42)



sns.kdeplot(train_data['total_bill'], color='blue', label='Training Set',)
sns.kdeplot(test_data['total_bill'], color='orange', label='Test Set', )

# Step 4: Add labels and legend
#plt.title('Comparison of Total Bill Distribution in Training and Test Sets(kde)')
plt.xlabel('Total Bill ($)')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
sns.histplot(train_data['total_bill'], color='blue', kde=True, label='Training Set', stat="density", bins=30)
sns.histplot(test_data['total_bill'], color='orange', kde=True, label='Test Set', stat="density", bins=30)

#plt.title('Comparison of Total Bill Distribution in Training and Test Sets(histogram)')

# %%
print("Training Set Shape:", X_train.shape)
print("Test Set Shape:", X_test.shape)

# %%
import seaborn as sns
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Step 1: Load the dataset
data = sns.load_dataset("tips")

# Step 2: Prepare features (X) and target (y)
X = data.drop(columns = ['tip'] )
y = data['tip']

# Step 3: Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=78)

# Step 4: Visualize distributions for X_train and X_test
plt.figure(figsize=(12, 6))

sns.kdeplot(X_train['total_bill'], color='blue', label='X_train (total_bill)', )
sns.kdeplot(X_test['total_bill'], color='orange',label='X_test (total_bill)', )

plt.title('Comparison of Total Bill in X_train and X_test')
plt.legend()
plt.show()

# Step 5: Visualize distributions for y_train and y_test
plt.figure(figsize=(12, 6))

sns.kdeplot(y_train, color='green', label='y_train',)
sns.kdeplot(y_test, color='red', label='y_test',)

plt.title('Comparison of Smoker (y_train vs y_test)')

plt.legend()
plt.show()

# %% [markdown]
# # Class Imbalance Visualizations
#
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the tips dataset
tips = sns.load_dataset('tips')
print(tips.head())

# %%
sns.barplot(tips['sex'])

# %%
sns.countplot(x='sex', data=tips)
plt.title('Count Plot of Gender in tips dataset')

plt.show()

# %%
sns.barplot(x=tips['sex'].value_counts().index,
            y=tips['sex'].value_counts().values,)
plt.title('Bar Plot of Gender')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the tips dataset
tips = sns.load_dataset('tips')

# Create a violin plot for the 'total_bill' by 'day'
sns.violinplot(x='sex', y='total_bill', data=tips, palette='mako')

# Title and labels
plt.title('Distribution of Total Bill by Day')
plt.xlabel('Day')
plt.ylabel('Total Bill')
plt.show()

# %%
# Create a strip plot for the 'total_bill' by 'day'
sns.stripplot(x='sex', y='total_bill', data=tips)

# Title and labels
plt.title('Individual Total Bill Values by Day')
plt.xlabel('sex')
plt.ylabel('Total Bill')
plt.show()

# %% [markdown]
# # Confusion matrix heatmaps for classification evaluation
#
# ---

# %% [markdown]
# Binary Classification:
#
# ---

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Sample Data
y_true = ["survived", "dead", "dead", "survived", "dead", "dead", "survived", "dead"]
y_pred = ["survived", "dead", "survived", "survived", "dead", "dead", "survived", "survived"]

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred, labels=["survived", "dead"])

# Heatmap Visualization
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["survived", "dead"], yticklabels=["survived", "dead"])
plt.title("Confusion Matrix Heatmap")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %%
cm

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

# %%
tips = sns.load_dataset('tips')
tips

# %%
# Seperating Features (X) and Target (y)
X = tips[['total_bill', 'size']]
y = (tips['smoker'])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)
y

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Train a logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# %%
# Predict on the test data
y_pred = model.predict(X_test)

# %%
# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred)
cm

# %%
# Visualize the confusion matrix as a heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', )
plt.title("Confusion Matrix Heatmap")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# Multi-Class Classification
#
# ---

# %%
iris

# %%
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# Load the Iris dataset from Seaborn
iris = sns.load_dataset('iris')

# Features (X) and Target (y)
X = iris[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]  # Numeric features
y = iris['species']  # Target: species (setosa, versicolor, virginica)

# Encode the target variable (species) into numerical values
le = LabelEncoder()
y = le.fit_transform(y)  # Converts species to 0, 1, 2

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train a logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Predict on the test data
y_pred = model.predict(X_test)

# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Visualize the confusion matrix as a heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.title("Confusion Matrix Heatmap (Iris from Seaborn)")
plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")
plt.show()

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

iris = sns.load_dataset('iris')

# Features (X) and Target (y)
x = iris[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]  # Numeric features
y = iris['species']  # Target: species (setosa, versicolor, virginica)

# Encode the target variable (species) into numerical values
le = LabelEncoder()
y = le.fit_transform(y)  # Converts species to 0, 1, 2

# Train-Test Split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# Fit Linear Regression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# Residuals
residuals=y_test - y_pred

# Residual Plot
plt.figure(figsize=(8,6))
sns.scatterplot(x=y_pred,y=residuals,color='purple')
plt.axhline(0,color='black',linestyle='--')
plt.title('Residual Plot')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.show()

# %%
sns.load_dataset('penguins')

# %% [markdown]
# # Residual plots to assess regression model fit
#
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import numpy as np

# Load the Tips dataset
tips = sns.load_dataset('tips')

# Features (X) and Target (y)
X = tips[['total_bill']]  # Feature: total_bill
y = tips['tip']  # Target: tip

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train a linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict on the test data
y_pred = model.predict(X_test)

# Calculate the residuals (difference between actual and predicted values)
residuals = y_test - y_pred

# Plotting the residuals
plt.figure(figsize=(8, 6))
plt.scatter(y_pred, residuals, color='blue', edgecolors='black')
plt.axhline(y=0, color='r', linestyle='--')  # Red horizontal line at 0
plt.title('Residual Plot (Total Bill vs Tip)')
plt.xlabel('Predicted Tip')
plt.ylabel('Residuals (Actual - Predicted)')
plt.show()

# %%
# import packages and libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols

# reading the csv file
data = pd.read_csv('headbrain3.csv')

# fit simple linear regression model
linear_model = ols('Brain_weight ~ Head_size',
				data=data).fit()

# display model summary
print(linear_model.summary())

# modify figure size
fig = plt.figure(figsize=(14, 8))

# creating regression plots
fig = sm.graphics.plot_regress_exog(linear_model,
									'Head_size',
									fig=fig)
